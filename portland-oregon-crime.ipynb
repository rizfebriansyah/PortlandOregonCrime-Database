# %%
import pandas as pd

# %%
# this is to retrieve and load the csv file to pandas' dataframe. This is for preliminary investigation and formatting purposes

df = pd.read_csv('portland_oregeon_crime.csv', header= 0, encoding= 'unicode_escape')
df.head(10)
# Out:
#                           Address Case Number Crime Against  Neighborhood  \
# 0       3600 BLOCK OF SE KNAPP ST   17-902332      Property  Eastmoreland
# 1     3600 BLOCK OF SE LAMBERT ST   17-902346      Property  Eastmoreland
# 2       7200 BLOCK OF SE 32ND AVE   17-902450      Property  Eastmoreland
# 3       6500 BLOCK OF SE 32ND AVE   17-902495      Property  Eastmoreland
# 4         500 BLOCK OF N DIXON ST   17-901848      Property         Eliot
# 5       2200 BLOCK OF N FLINT AVE    17-33224      Property         Eliot
# 6         400 BLOCK OF N DIXON ST   17-902972      Property         Eliot
# 7    1900 BLOCK OF N WILLIAMS AVE   17-901378      Property         Eliot
# 8   500 BLOCK OF NE SACRAMENTO ST    17-36779      Property         Eliot
# 9  1500 BLOCK OF N INTERSTATE AVE    17-37320      Property         Eliot
#
#    Number of Records  Occur Date Occur Month Year  Occur Time  \
# 0                  1   2/20/2017         2/1/2017           0
# ...

# %%
# this is to convert MM/DD/YYYY to YYYY-MM-DD on the Occur Date column
df['Occur Date'] = pd.to_datetime(df['Occur Date']).dt.strftime('%Y-%m-%d')

# %%
df.head(10)
# Out:
#                           Address Case Number Crime Against  Neighborhood  \
# 0       3600 BLOCK OF SE KNAPP ST   17-902332      Property  Eastmoreland
# 1     3600 BLOCK OF SE LAMBERT ST   17-902346      Property  Eastmoreland
# 2       7200 BLOCK OF SE 32ND AVE   17-902450      Property  Eastmoreland
# 3       6500 BLOCK OF SE 32ND AVE   17-902495      Property  Eastmoreland
# 4         500 BLOCK OF N DIXON ST   17-901848      Property         Eliot
# 5       2200 BLOCK OF N FLINT AVE    17-33224      Property         Eliot
# 6         400 BLOCK OF N DIXON ST   17-902972      Property         Eliot
# 7    1900 BLOCK OF N WILLIAMS AVE   17-901378      Property         Eliot
# 8   500 BLOCK OF NE SACRAMENTO ST    17-36779      Property         Eliot
# 9  1500 BLOCK OF N INTERSTATE AVE    17-37320      Property         Eliot
#
#    Number of Records  Occur Date Occur Month Year  Occur Time  \
# 0                  1  2017-02-20         2/1/2017           0
# ...

# %%
# remove all NaN values in Address column to Not Available 
df['Address'].fillna('NOT AVAILABLE', inplace = True)

# remove all NaN values in Neighborhood column to Not Available 
df['Neighborhood'].fillna('NOT AVAILABLE', inplace = True)

# remove all NaN values in OpenDataLat column to Not Available 
df['OpenDataLat'].fillna('NOT AVAILABLE', inplace = True)

# remove all NaN values in OpenDataLon column to Not Available 
df['OpenDataLon'].fillna('NOT AVAILABLE', inplace = True)

# %%
# to display and check if NaN values have been converted
df.head(20)
# Out:
#                                         Address Case Number Crime Against  \
# 0                     3600 BLOCK OF SE KNAPP ST   17-902332      Property
# 1                   3600 BLOCK OF SE LAMBERT ST   17-902346      Property
# 2                     7200 BLOCK OF SE 32ND AVE   17-902450      Property
# 3                     6500 BLOCK OF SE 32ND AVE   17-902495      Property
# 4                       500 BLOCK OF N DIXON ST   17-901848      Property
# 5                     2200 BLOCK OF N FLINT AVE    17-33224      Property
# 6                       400 BLOCK OF N DIXON ST   17-902972      Property
# 7                  1900 BLOCK OF N WILLIAMS AVE   17-901378      Property
# 8                 500 BLOCK OF NE SACRAMENTO ST    17-36779      Property
# 9                1500 BLOCK OF N INTERSTATE AVE    17-37320      Property
# 10                   300 BLOCK OF NE RUSSELL ST    17-37361      Property
# 11                  3300 BLOCK OF NE RODNEY AVE    17-37647      Property
# ...

# %%
# this is to remove all the columns which is not needed
df = df.drop(columns=['Offense Category' , 'Crime Against', 'Number of Records', 'Occur Month Year', 'Occur Time', 'Offense Count',  'OpenDataX', 'OpenDataY', 'Report Date', 'ReportMonthYear'])

# %%
# to check if the data has been cleaned 
df.head(5)
# Out:
#                        Address Case Number  Neighborhood  Occur Date  \
# 0    3600 BLOCK OF SE KNAPP ST   17-902332  Eastmoreland  2017-02-20
# 1  3600 BLOCK OF SE LAMBERT ST   17-902346  Eastmoreland  2017-02-20
# 2    7200 BLOCK OF SE 32ND AVE   17-902450  Eastmoreland  2017-02-21
# 3    6500 BLOCK OF SE 32ND AVE   17-902495  Eastmoreland  2017-02-21
# 4      500 BLOCK OF N DIXON ST   17-901848         Eliot  2016-12-21
#
#                Offense Type OpenDataLat OpenDataLon
# 0  Theft From Motor Vehicle     45.4705    -122.625
# 1  Theft From Motor Vehicle      45.467    -122.625
# 2  Theft From Motor Vehicle     45.4719     -122.63
# 3  Theft From Motor Vehicle     45.4752     -122.63
# 4  Theft From Motor Vehicle     45.5346    -122.672

# %%
# this is to replace all the - with an empty space on the case number column
df['Case Number'] = df['Case Number'].apply(lambda x: x.replace('-',''))

# %%
# drop duplicate in Case Number
df = df.drop_duplicates(['Case Number'], keep=False)

# %%
# save and export the edited .csv file 
df.to_csv('portland-oregon-crime-cleaned.csv', index = False)
